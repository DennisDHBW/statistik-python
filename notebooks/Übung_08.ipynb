# %% [markdown]
# # Übung zur Vorlesung 8 - Clustering

# %%
# Erzeugen der Beispieldaten

from sklearn.datasets import make_blobs
#import matplotlib.pyplot as plt

n_samples = 500
n_c = 5
X, y = make_blobs(n_samples=n_samples, centers=n_c, random_state=42)

#plt.scatter(X[:, 0], X[:, 1], c=y, cmap='viridis')
#plt.title(f'Generierte Daten')
#plt.show()

# %% [markdown]
# ## Aufgabe Teil 1 - K-Means
# 1. Finden Sie mit Hilfe der Elbow-Methode eine passende Clusteranzahl.
# 2. Stellen Sie das Ergebnis des Clusterings in einem Punkte-Plot durch unterschiedliche Farben für die unterschiedlichen Cluster dar.

# %%
# Input Daten sind in der Variable X gespeichert:
X

# TODO: Elbow-Methode zur Identifikation der Clusteranzahl
inertia = []
K = range(1, 11)
# 2. Run K-Means for various values of k
for k in K:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)

# TODO: Grafische Darstellung des Clustering Ergebnisses
plt.figure(figsize=(8, 5))
plt.plot(K, inertia, 'bx-')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Inertia')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %% [markdown]
# ## Aufgabe Teil 2 - Hierarchisches Clustering
# 1. Führen Sie den agglomerativen Algorithmus durch und erstellen Sie ein Dendrogramm.
# 2. Stellen Sie das Ergebnis des Clusterings in einem Punkte-Plot durch unterschiedliche Farben für die unterschiedlichen Cluster dar.

# %%
# Input Daten sind in der Variable X gespeichert:
X

# TODO: Elbow-Methode zur Identifikation der Clusteranzahl



# TODO: Grafische Darstellung des Clustering Ergebnisses
# Out:
# array([[  4.62763206,   1.07591531],
#        [  1.93256454,   5.60156877],
#        [  0.74199584,   5.03390888],
#        [  1.3986115 ,   0.94878204],
#        [ -8.75041911,  -7.23162308],
#        [  3.9095122 ,   2.18962827],
#        [ -5.71184513,  -6.62568875],
#        [  2.31146888,   6.6167517 ],
#        [ -2.21307735,   9.2753414 ],
#        [ -2.58629933,   9.3554381 ],
#        [  5.38717244,   2.58353995],
#        [  4.68545068,   1.32156934],
#        [  3.04545118,   1.37379466],
#        [  1.47007719,   4.79438337],
#        [ -8.87331625,   9.09432355],
#        [ -9.09330497,   8.8275159 ],
#        [  4.16794697,   3.06212028],
#        [-11.48929757,   8.41502977],
#        [ -7.53026976,  -7.36723498],
#        [  3.19179449,   0.56570591],
#        [  2.63019674,   4.34806068],
#        [ -9.54267145,   5.91506162],
#        [ -5.25101165,  -8.26021105],
#        [ -9.761561  ,   5.97183831],
#        [ -2.1475616 ,   8.36916637],
# ...
